# %%
# pip install snscrape

import snscrape.modules.twitter as sntwitter
import pandas as pd


tweets = []
c = 0

query = '(که OR از OR به OR با OR در) lang:fa since:2022-01-01 min_retweets:23'
for tweet in sntwitter.TwitterSearchScraper(query).get_items():
    tweets.append({'date' : tweet.date,
    'text' : tweet.rawContent,
    'Id' : tweet.id,
    'hashtags' : tweet.hashtags,
    'mentionedUsers' : tweet.mentionedUsers,
    'sourceLabel' : tweet.sourceLabel,
    'sourceUrl' : tweet.sourceUrl,
    'lang' : tweet.lang,
    'likeCount' : tweet.likeCount,
    'retweetCount' : tweet.retweetCount,
    'replyCount' : tweet.replyCount,
    'Username' : tweet.user.username,
    "User_id" : tweet.user.id,
    'User_description' : tweet.user.renderedDescription,
    "User_created" : tweet.user.created,
    "UserfollowersCount" : tweet.user.followersCount,
    "Userlocation" : tweet.user.location,
    'UserprofileBannerUrl' : tweet.user.profileBannerUrl,
    "UserprofileBannerUrl" : tweet.user.profileBannerUrl,
    "USermediaCount" : tweet.user.mediaCount,
    "UserfollowingCount" : tweet.user.friendsCount})
    c += 1
    if c%1000 == 999:
        print(c)
        print(tweet.date)
        df = pd.DataFrame(tweets)
        df.to_csv(f"moset_tetweeted_index_{c}.csv")
        tweets = []
    


df = pd.DataFrame(tweets)
df.to_csv(f"moset_tetweeted_index_{c}_last.csv")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_14668\1851509156.py in <module>
#       9
#      10 query = '(که OR از OR به OR با OR در) lang:fa since:2022-01-01 until:2022-02-01 min_retweets:10'
# ---> 11 for tweet in sntwitter.TwitterSearchScraper(query).get_items():
#      12     tweets.append({'date' : tweet.date,
#      13     'text' : tweet.rawContent,
#
# ~\AppData\Roaming\Python\Python39\site-packages\snscrape\modules\twitter.py in get_items(self)
#    1655                 del params['cursor']
#    1656
# -> 1657                 for obj in self._iter_api_data('https://api.twitter.com/2/search/adaptive.json', _TwitterAPIType.V2, params, paginationParams, cursor = self._cursor):
#    1658                         yield from self._v2_timeline_instructions_to_tweets_or_users(obj)
#    1659
#
# ...
